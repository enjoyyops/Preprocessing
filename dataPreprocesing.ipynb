# %%
import pandas as pd
df = pd.read_csv('mental_illness.csv')
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %% [markdown]
# <table border="1">
#   <thead>
#     <tr>
#       <th>Skenario Analisis</th>
#       <th>Deskripsi Insight yang Dapat Dihasilkan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1. Tren Waktu Tiap Jenis Gangguan</td>
#       <td>Melihat perubahan prevalensi gangguan seperti depresi, skizofrenia, dan kecemasan dari tahun ke tahun di satu negara.</td>
#     </tr>
#     <tr>
#       <td>2. Perbandingan Antar Negara</td>
#       <td>Menganalisis negara dengan prevalensi tertinggi/rendah untuk masing-masing gangguan.</td>
#     </tr>
#     <tr>
#       <td>3. Identifikasi Gangguan Mental Paling Umum</td>
#       <td>Menentukan gangguan mental yang paling banyak dialami penduduk secara global maupun regional.</td>
#     </tr>
#     <tr>
#       <td>4. Korelasi Antar Jenis Gangguan</td>
#       <td>Melihat apakah ada korelasi antar gangguan, misalnya apakah peningkatan gangguan kecemasan sejalan dengan depresi.</td>
#     </tr>
#     <tr>
#       <td>5. Pemetaan Geospasial</td>
#       <td>Membuat peta dunia atau regional untuk menunjukkan distribusi gangguan mental secara visual.</td>
#     </tr>
#     <tr>
#       <td>6. Analisis Usia dan Jenis Kelamin (jika tersedia)</td>
#       <td>Jika data dibagi berdasarkan gender/usia, dapat dilakukan analisis siapa yang lebih rentan terhadap gangguan tertentu.</td>
#     </tr>
#   </tbody>
# </table>
